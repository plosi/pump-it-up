# %%
## General Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("~/Coding/drivendata/pump-it-up/data/df_clean.csv")
display(df.info())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   gps_height             59400 non-null  float64
#  2   installer              59400 non-null  object
#  3   private_conn           59400 non-null  int64
#  4   basin                  59400 non-null  object
#  5   region                 59400 non-null  object
#  6   population             59400 non-null  float64
#  7   public_meeting         59400 non-null  object
#  8   permit                 59400 non-null  object
#  9   extraction_type_class  59400 non-null  object
#  10  management_group       59400 non-null  object
#  11  payment_type           59400 non-null  object
#  12  quality_group          59400 non-null  object
#  13  quantity_group         59400 non-null  object
# ...

# %% [markdown]
# ### Creating dummy variables

# %%
cat_cols = df.drop('status_group', axis=1).select_dtypes(include='object').columns

cat_cols = cat_cols.to_list()
cat_cols.append('month_recorded')
dff = pd.get_dummies(data=df, columns=cat_cols, drop_first=True)
# df.select_dtypes(include='object').iloc[:,10].value_counts()

# %%
dff.shape
# Out:
# (59400, 88)

# %%
dff.sample(10)
# Out:
#           id   gps_height  private_conn  population    status_group  \
# 449     4923  1057.545585             0       200.0      functional
# 38340  71069  1392.000000             0      1903.0  non functional
# 51976  59811   -17.000000             0       150.0      functional
# 51261  39660  1152.000000             0        80.0      functional
# 14651  46646  1057.545585             0       200.0  non functional
# 6700   72542   487.000000             0       150.0      functional
# 54864   5202  1539.000000             0       532.0  non functional
# 27538   9475  1057.545585             0       200.0  non functional
# 35136  68989  1089.000000             0        30.0  non functional
# 14534  64548  1613.000000             0       350.0      functional
#
#        rainy_season  age_yrs  installer_government  installer_other  \
# 449               1     13.0                 False             True
# 38340             0     14.0                 False             True
# ...

# %%
dff.select_dtypes(include=['int','float'])
# Out:
#           id   gps_height  private_conn  population  rainy_season  age_yrs
# 0      69572  1390.000000             0       109.0             1     12.0
# 1       8776  1399.000000             0       280.0             1      3.0
# 2      34310   686.000000             0       250.0             0      4.0
# 3      67743   263.000000             0        58.0             0     27.0
# 4      19728  1057.545585             0       200.0             0      8.0
# ...      ...          ...           ...         ...           ...      ...
# 59395  60739  1210.000000             0       125.0             1     14.0
# 59396  27263  1212.000000             0        56.0             1     15.0
# 59397  37057  1057.545585             0       200.0             1      8.0
# 59398  31282  1057.545585             0       200.0             1     13.0
# 59399  26348   191.000000             0       150.0             1      9.0
#
# [59400 rows x 6 columns]

# %%
cols_to_scale = ['gps_height', 'population', 'age_yrs']
